# %% [markdown]
# # MLP with RMSprop Using Tensorflow - Tuning

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.optimizers.legacy import RMSprop
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
import wandb
from pprint import pprint

from tf_utils import create_model, train_model

# %% [markdown]
# ## Login to Wandb

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ## Load Fashion-MNIST

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# ## Define sweep agent function

# %%
def sweep_train():
    default_config = {
        'dense_1': 512,
        'dense_2': 256,
        'dense_3': 256,
        'dense_4': 64,
        'learning_rate': 0.001,
        'momentum': 0.0,
        'rho': 0.9,
        'epochs': 50,
        'batch_size': 128,
    }

    wandb.init(config=default_config)

    config = wandb.config

    mlp = create_model(config)
    mlp.summary()
    mlp.compile(
        optimizer=RMSprop(learning_rate=config.learning_rate, momentum=config.momentum, rho=config.rho),
        loss=SparseCategoricalCrossentropy(),
        metrics=[SparseCategoricalAccuracy()]
    )
    _ = train_model(mlp, config, x_train, y_train, verbose=0)

# %% [markdown]
# ## Configure Wandb Sweep for hyperparameter tuning

# %%
sweep_config = {
    'name': 'tf-rmsprop-sweep',
    'method': 'bayes',
    'metric': {
        'name': 'val_loss',
        'goal': 'minimize'
    },
    'early_terminate':{
        'type': 'hyperband',
        'min_iter': 2
    },
    'parameters': {
        'batch_size': {
            'values': [16, 32, 64, 128, 256]
        },
        'epochs': {
            'min': 15,
            'max': 50
        },
        'learning_rate': {
            'min': 0.0001,
            'max': 0.1
        },
        'momentum': {
            'min': 0.0,
            'max': 0.9
        },
        'rho': {
            'min': 0.8,
            'max': 0.999
        },
        'dense_1': {
            'min': 256,
            'max': 512
        },
        'dense_2': {
            'min': 128,
            'max': 256
        },
        'dense_3': {
            'min': 128,
            'max': 256
        },
        'dense_4': {
            'min': 32,
            'max': 128
        }
    }
}

pprint(sweep_config)

sweep_id = wandb.sweep(sweep_config, project='tf_mlp')
# Out:
# {'early_terminate': {'min_iter': 2, 'type': 'hyperband'},
#  'method': 'bayes',
#  'metric': {'goal': 'minimize', 'name': 'val_loss'},
#  'name': 'tf-rmsprop-sweep',
#  'parameters': {'batch_size': {'values': [16, 32, 64, 128, 256]},
#                 'dense_1': {'max': 512, 'min': 256},
#                 'dense_2': {'max': 256, 'min': 128},
#                 'dense_3': {'max': 256, 'min': 128},
#                 'dense_4': {'max': 128, 'min': 32},
#                 'epochs': {'max': 50, 'min': 15},
#                 'learning_rate': {'max': 0.1, 'min': 0.0001},
#                 'momentum': {'max': 0.9, 'min': 0.0},
#                 'rho': {'max': 0.999, 'min': 0.8}}}
# Create sweep with ID: 9v74y3nr
# Sweep URL: https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr

# %% [markdown]
# ## Run sweep

# %%
wandb.agent(sweep_id, function=sweep_train, count=50)
# Out:
# wandb: Agent Starting Run: aemtzbdi with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 278
# wandb: 	dense_2: 208
# wandb: 	dense_3: 192
# wandb: 	dense_4: 90
# wandb: 	epochs: 21
# wandb: 	learning_rate: 0.08327647189609565
# wandb: 	momentum: 0.08083622947220044
# wandb: 	rho: 0.8703079889871562
# wandb: Currently logged in as: v-modroczky (nsiete23). Use `wandb login --relogin` to force relogin
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_002425-aemtzbdi</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/aemtzbdi" target="_blank">atomic-sweep-1</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 278)               218230
#
#  dense_1 (Dense)             (None, 208)               58032
#
#  dense_2 (Dense)             (None, 192)               40128
#
#  dense_3 (Dense)             (None, 90)                17370
#
#  dense_4 (Dense)             (None, 10)                910
#
# =================================================================
# Total params: 334,670
# Trainable params: 334,670
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▂▁▂▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▄█▃█▂▄▃▂▁▃▇▄▆▂▆▃▅▃▃▇</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▅▅▅▃▃▆▃▅██▆▅▅▃▁▅▁▆▆▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00033</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>2.30516</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>2.30715</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.10023</td></tr><tr><td>val_loss</td><td>2.31358</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.09833</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">atomic-sweep-1</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/aemtzbdi" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/aemtzbdi</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_002425-aemtzbdi/logs</code>
# wandb: Agent Starting Run: stoz8iqq with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 349
# wandb: 	dense_2: 241
# wandb: 	dense_3: 148
# wandb: 	dense_4: 37
# wandb: 	epochs: 17
# wandb: 	learning_rate: 0.01217227859839216
# wandb: 	momentum: 0.10856137222328777
# wandb: 	rho: 0.8583339085500451
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_002521-stoz8iqq</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/stoz8iqq" target="_blank">robust-sweep-2</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 349)               273965
#
#  dense_1 (Dense)             (None, 241)               84350
#
#  dense_2 (Dense)             (None, 148)               35816
#
#  dense_3 (Dense)             (None, 37)                5513
#
#  dense_4 (Dense)             (None, 10)                380
#
# =================================================================
# Total params: 400,024
# Trainable params: 400,024
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▆▇▇▇████████████</td></tr><tr><td>val_loss</td><td>▅▄▆▄▂█▃▁▂▄▂▅▂▃▃▁▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▁▂▄▇▂▅█▇▆▇▆▇▇▅█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.0004</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.424</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.388</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.86931</td></tr><tr><td>val_loss</td><td>0.48543</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.84792</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">robust-sweep-2</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/stoz8iqq" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/stoz8iqq</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_002521-stoz8iqq/logs</code>
# wandb: Agent Starting Run: imh7sboz with config:
# wandb: 	batch_size: 128
# wandb: 	dense_1: 463
# wandb: 	dense_2: 163
# wandb: 	dense_3: 183
# wandb: 	dense_4: 57
# wandb: 	epochs: 27
# wandb: 	learning_rate: 0.05458373179595338
# wandb: 	momentum: 0.3814439264263261
# wandb: 	rho: 0.9841393790585384
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_002612-imh7sboz</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/imh7sboz" target="_blank">lilac-sweep-3</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 463)               363455
#
#  dense_1 (Dense)             (None, 163)               75632
#
#  dense_2 (Dense)             (None, 183)               30012
#
#  dense_3 (Dense)             (None, 57)                10488
#
#  dense_4 (Dense)             (None, 10)                580
#
# =================================================================
# Total params: 480,167
# Trainable params: 480,167
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▅▃▃▆▇▄▄▃▃▅█▁▃▅▄▆▅▅▂▃▅▄▂▆▄▃▄</td></tr><tr><td>val_loss</td><td>▃▃▄▂▃▂▅▂▂▃▃▃▁▃▂█▃▃▂▃▅▄▃▄▄▅▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▅▃▃█▆▆▅▅▁▁█▅█▆█▅█▁█▁▁▃▅▅▃▁▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00048</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>2.30383</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>2.30827</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.09938</td></tr><tr><td>val_loss</td><td>2.30526</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.10033</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lilac-sweep-3</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/imh7sboz" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/imh7sboz</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_002612-imh7sboz/logs</code>
# wandb: Agent Starting Run: bq18hv8j with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 474
# wandb: 	dense_2: 129
# wandb: 	dense_3: 167
# wandb: 	dense_4: 45
# wandb: 	epochs: 18
# wandb: 	learning_rate: 0.06467285371845305
# wandb: 	momentum: 0.3621442305158925
# wandb: 	rho: 0.8924118632848634
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_002719-bq18hv8j</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/bq18hv8j" target="_blank">generous-sweep-4</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 474)               372090
#
#  dense_1 (Dense)             (None, 129)               61275
#
#  dense_2 (Dense)             (None, 167)               21710
#
#  dense_3 (Dense)             (None, 45)                7560
#
#  dense_4 (Dense)             (None, 10)                460
#
# =================================================================
# Total params: 463,095
# Trainable params: 463,095
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▄▃▃▅▄▄█▆▄▆▃▄▄▁▄▅▄▂</td></tr><tr><td>val_loss</td><td>▂▄▄▂▄▄▃▆▁▄▄▃▂▁▃▄▄█</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▃▃▅▆▆▅▁█▅▅▁▃▆▃▆▆▁▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00046</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>2.30522</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>2.30708</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.09775</td></tr><tr><td>val_loss</td><td>2.31763</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.10033</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">generous-sweep-4</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/bq18hv8j" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/bq18hv8j</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_002719-bq18hv8j/logs</code>
# wandb: Agent Starting Run: xwdo93k9 with config:
# wandb: 	batch_size: 64
# wandb: 	dense_1: 302
# wandb: 	dense_2: 256
# wandb: 	dense_3: 165
# wandb: 	dense_4: 33
# wandb: 	epochs: 22
# wandb: 	learning_rate: 0.01880595289682616
# wandb: 	momentum: 0.28782322374795966
# wandb: 	rho: 0.8596431372947871
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_002810-xwdo93k9</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/xwdo93k9" target="_blank">polar-sweep-5</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 302)               237070
#
#  dense_1 (Dense)             (None, 256)               77568
#
#  dense_2 (Dense)             (None, 165)               42405
#
#  dense_3 (Dense)             (None, 33)                5478
#
#  dense_4 (Dense)             (None, 10)                340
#
# =================================================================
# Total params: 362,861
# Trainable params: 362,861
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▂▂▂▁▁▁▁▁▁▁▁▂▁▁▁▂▂</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▇▇▇█▇▅▆▇█████▇▇▇█▇█▇▇</td></tr><tr><td>val_loss</td><td>▃▄▂▃▂▄▇▃▁█▅▆▃▃▇▁█▄▅▆▅▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▇▂▇▄▇▆▁██▇▄▆▇█▂█▄▃▂▅▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00036</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.65377</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.7274</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.77142</td></tr><tr><td>val_loss</td><td>0.69305</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.79808</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">polar-sweep-5</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/xwdo93k9" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/xwdo93k9</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_002810-xwdo93k9/logs</code>
# wandb: Agent Starting Run: u171q77d with config:
# wandb: 	batch_size: 64
# wandb: 	dense_1: 382
# wandb: 	dense_2: 237
# wandb: 	dense_3: 147
# wandb: 	dense_4: 32
# wandb: 	epochs: 19
# wandb: 	learning_rate: 0.008360766348959837
# wandb: 	momentum: 0.010535267791107462
# wandb: 	rho: 0.8578567709086986
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_002957-u171q77d</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/u171q77d" target="_blank">resilient-sweep-6</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 382)               299870
#
#  dense_1 (Dense)             (None, 237)               90771
#
#  dense_2 (Dense)             (None, 147)               34986
#
#  dense_3 (Dense)             (None, 32)                4736
#
#  dense_4 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 430,693
# Trainable params: 430,693
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>▂▁▁▁▁▁▁▁▁▂▂▂▂▃▄▆▆██</td></tr><tr><td>sparse_categorical_accuracy</td><td>▆████████▇▇▇▇▆▅▃▂▂▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▅▁▂▂▂█▂▃▃▃▃</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▇▇██████▇█▆▇█▆▅▃▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00043</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.49946</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>2.36404</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.42973</td></tr><tr><td>val_loss</td><td>1.59231</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.39283</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">resilient-sweep-6</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/u171q77d" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/u171q77d</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_002957-u171q77d/logs</code>
# wandb: Agent Starting Run: wwgga1yd with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 311
# wandb: 	dense_2: 238
# wandb: 	dense_3: 129
# wandb: 	dense_4: 38
# wandb: 	epochs: 27
# wandb: 	learning_rate: 0.007199572771229585
# wandb: 	momentum: 0.325748377729711
# wandb: 	rho: 0.8444886374843534
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_003143-wwgga1yd</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/wwgga1yd" target="_blank">blooming-sweep-7</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 311)               244135
#
#  dense_1 (Dense)             (None, 238)               74256
#
#  dense_2 (Dense)             (None, 129)               30831
#
#  dense_3 (Dense)             (None, 38)                4940
#
#  dense_4 (Dense)             (None, 10)                390
#
# =================================================================
# Total params: 354,552
# Trainable params: 354,552
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▆▆▇▇▇▇████████████████████</td></tr><tr><td>val_loss</td><td>▃▂▂▃▂▂▃▂▂▁▂▂▁▁▂▂▂▃▂▂▂▃▃▂▃█▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▅▅▃▅▅▂▆▆▇▇▅██▆▆▅▅▇▇█▄▆▆▇▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00035</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.39455</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.34851</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.88262</td></tr><tr><td>val_loss</td><td>0.48784</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.87333</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">blooming-sweep-7</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/wwgga1yd" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/wwgga1yd</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_003143-wwgga1yd/logs</code>
# wandb: Agent Starting Run: 3511mpna with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 292
# wandb: 	dense_2: 246
# wandb: 	dense_3: 187
# wandb: 	dense_4: 78
# wandb: 	epochs: 36
# wandb: 	learning_rate: 0.004025579531438728
# wandb: 	momentum: 0.5810420065050655
# wandb: 	rho: 0.8011256363807325
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_003234-3511mpna</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/3511mpna" target="_blank">proud-sweep-8</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 292)               229220
#
#  dense_1 (Dense)             (None, 246)               72078
#
#  dense_2 (Dense)             (None, 187)               46189
#
#  dense_3 (Dense)             (None, 78)                14664
#
#  dense_4 (Dense)             (None, 10)                790
#
# =================================================================
# Total params: 362,941
# Trainable params: 362,941
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▂▂▃▂▂▂▂▃▃▃▄</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▆▇▇▇▇████████████████████▇▇██▇▇▇▇▇▇</td></tr><tr><td>val_loss</td><td>▃▁▂▄▁▁▁▁▁▁▂▃▁▃▂▃▃▂▂▅▂▄▂▄▄▃█▄▇▅▅▅▄█▄▄</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▂▆▄▄▆▇▇█▆▇▇▄▇▆▇▆▅▇▅▇▇█▆▇▇▆▆▆▅▃▇▆▃▁▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00036</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.41464</td></tr><tr><td>epoch</td><td>35</td></tr><tr><td>loss</td><td>0.51774</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.86256</td></tr><tr><td>val_loss</td><td>0.70371</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.83567</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">proud-sweep-8</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/3511mpna" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/3511mpna</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_003234-3511mpna/logs</code>
# wandb: Agent Starting Run: cm6l30ke with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 320
# wandb: 	dense_2: 243
# wandb: 	dense_3: 160
# wandb: 	dense_4: 52
# wandb: 	epochs: 32
# wandb: 	learning_rate: 0.0144763824410983
# wandb: 	momentum: 0.8903660810280439
# wandb: 	rho: 0.8281803726316771
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_003330-cm6l30ke</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/cm6l30ke" target="_blank">giddy-sweep-9</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 320)               251200
#
#  dense_1 (Dense)             (None, 243)               78003
#
#  dense_2 (Dense)             (None, 160)               39040
#
#  dense_3 (Dense)             (None, 52)                8372
#
#  dense_4 (Dense)             (None, 10)                530
#
# =================================================================
# Total params: 377,145
# Trainable params: 377,145
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>▄▁▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>█▄▂▁▄▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>val_loss</td><td>█▂▂▂▂▁▁▁▂▂▂▃▂▂▂▁▁▁▂▁▁▁▁▂▂▂▂▂▂▂▂▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▂█▄▄▄▄▃▅▄▄▃▁▃▄▄▅▃▄▄▅▅▄▄▄▃▄▅▄▅▁▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00038</td></tr><tr><td>best_epoch</td><td>22</td></tr><tr><td>best_val_loss</td><td>1.70293</td></tr><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>1.79651</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.19883</td></tr><tr><td>val_loss</td><td>1.80688</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.19483</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">giddy-sweep-9</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/cm6l30ke" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/cm6l30ke</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_003330-cm6l30ke/logs</code>
# wandb: Agent Starting Run: 0b7i4mmp with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 278
# wandb: 	dense_2: 250
# wandb: 	dense_3: 157
# wandb: 	dense_4: 51
# wandb: 	epochs: 38
# wandb: 	learning_rate: 0.03880061034994843
# wandb: 	momentum: 0.05063768420812496
# wandb: 	rho: 0.8023360271856302
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_003427-0b7i4mmp</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/0b7i4mmp" target="_blank">gentle-sweep-10</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 278)               218230
#
#  dense_1 (Dense)             (None, 250)               69750
#
#  dense_2 (Dense)             (None, 157)               39407
#
#  dense_3 (Dense)             (None, 51)                8058
#
#  dense_4 (Dense)             (None, 10)                520
#
# =================================================================
# Total params: 335,965
# Trainable params: 335,965
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▆▆▆▇▇▇▆▆▇▇███████████▇█████████████</td></tr><tr><td>val_loss</td><td>█▆█▅▄▄▃▆▆▅▄▄▃▁▁▂▃▁▂▁▁▄▂▂▃▇▄▃▁▄▂▂▃▃▄▂▂▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▅▂▅▅▅▅▄▅▃▆▅▆▇▇▇▆█▇██▄██▇▇▄▇█▆██▇▇▆█▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00034</td></tr><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.65958</td></tr><tr><td>epoch</td><td>37</td></tr><tr><td>loss</td><td>0.68519</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.75815</td></tr><tr><td>val_loss</td><td>0.68954</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.77475</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">gentle-sweep-10</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/0b7i4mmp" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/0b7i4mmp</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_003427-0b7i4mmp/logs</code>
# wandb: Agent Starting Run: knnrdjww with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 305
# wandb: 	dense_2: 226
# wandb: 	dense_3: 185
# wandb: 	dense_4: 86
# wandb: 	epochs: 41
# wandb: 	learning_rate: 0.009427385386421709
# wandb: 	momentum: 0.2797902166155888
# wandb: 	rho: 0.8321748314323335
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_003533-knnrdjww</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/knnrdjww" target="_blank">pretty-sweep-11</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 305)               239425
#
#  dense_1 (Dense)             (None, 226)               69156
#
#  dense_2 (Dense)             (None, 185)               41995
#
#  dense_3 (Dense)             (None, 86)                15996
#
#  dense_4 (Dense)             (None, 10)                870
#
# =================================================================
# Total params: 367,442
# Trainable params: 367,442
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▆▇▇▇▇▇█▇███████████████████████████████</td></tr><tr><td>val_loss</td><td>▃▃▂▂▂▂▆▂▄▂▃▂▅▁▃▂▂▂▂▁▂▄▄▃▃█▃▄▃▂▄▂▃▃▄▃▃▇▅▄</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▄▆▅▄▆▃▅▄▇▅▇▃█▅▇▇▇▇▇▇▄▆▆▅▅▇█▅▇▅██▆▅▆▇▇▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00037</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.40585</td></tr><tr><td>epoch</td><td>40</td></tr><tr><td>loss</td><td>0.41192</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.86721</td></tr><tr><td>val_loss</td><td>0.5954</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.86217</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">pretty-sweep-11</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/knnrdjww" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/knnrdjww</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_003533-knnrdjww/logs</code>
# wandb: Agent Starting Run: gptzdl0w with config:
# wandb: 	batch_size: 128
# wandb: 	dense_1: 291
# wandb: 	dense_2: 210
# wandb: 	dense_3: 223
# wandb: 	dense_4: 40
# wandb: 	epochs: 44
# wandb: 	learning_rate: 0.011024057629431807
# wandb: 	momentum: 0.25733191320033955
# wandb: 	rho: 0.8288577338228731
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_003630-gptzdl0w</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/gptzdl0w" target="_blank">super-sweep-12</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 291)               228435
#
#  dense_1 (Dense)             (None, 210)               61320
#
#  dense_2 (Dense)             (None, 223)               47053
#
#  dense_3 (Dense)             (None, 40)                8960
#
#  dense_4 (Dense)             (None, 10)                410
#
# =================================================================
# Total params: 346,178
# Trainable params: 346,178
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/12wyczm4" target="_blank">faithful-sweep-47</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 414)               324990
#
#  dense_1 (Dense)             (None, 247)               102505
#
#  dense_2 (Dense)             (None, 136)               33728
#
#  dense_3 (Dense)             (None, 107)               14659
#
#  dense_4 (Dense)             (None, 10)                1080
#
# =================================================================
# Total params: 476,962
# Trainable params: 476,962
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▆▇▇▇▇▇▇▇█████████</td></tr><tr><td>val_loss</td><td>▆▄█▂▃▅▁▂▂▂▄▁▂▂▁▃▂▂▂▃</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▃▅▁▇▆▆▇▆▇▇▆█▇██▇▇▇█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00048</td></tr><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.34558</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.23478</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.91177</td></tr><tr><td>val_loss</td><td>0.40607</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.8745</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">faithful-sweep-47</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/12wyczm4" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/12wyczm4</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_011313-12wyczm4/logs</code>
# wandb: Agent Starting Run: ehazmneb with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 258
# wandb: 	dense_2: 169
# wandb: 	dense_3: 135
# wandb: 	dense_4: 122
# wandb: 	epochs: 32
# wandb: 	learning_rate: 0.0010263319224626468
# wandb: 	momentum: 0.011490379930376394
# wandb: 	rho: 0.969398198824563
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_011404-ehazmneb</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/ehazmneb" target="_blank">stoic-sweep-48</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 258)               202530
#
#  dense_1 (Dense)             (None, 169)               43771
#
#  dense_2 (Dense)             (None, 135)               22950
#
#  dense_3 (Dense)             (None, 122)               16592
#
#  dense_4 (Dense)             (None, 10)                1230
#
# =================================================================
# Total params: 287,073
# Trainable params: 287,073
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>val_loss</td><td>▇▅▃▃▂▂▃▃▂▃▂▂▂▂▂▂▁▂▃▂▂▂▃█▃▃▃▆▅▃▃▅</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▁▄▅▆▆▅▅▇▅▇▇▇▇▇▇█▆▆███▇▄██▇▆▅▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00029</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.32195</td></tr><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>0.12384</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.95125</td></tr><tr><td>val_loss</td><td>0.46896</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.89108</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">stoic-sweep-48</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/ehazmneb" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/ehazmneb</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_011404-ehazmneb/logs</code>
# wandb: Agent Starting Run: 6zxxjczl with config:
# wandb: 	batch_size: 256
# wandb: 	dense_1: 373
# wandb: 	dense_2: 230
# wandb: 	dense_3: 168
# wandb: 	dense_4: 120
# wandb: 	epochs: 34
# wandb: 	learning_rate: 0.0008461161112629131
# wandb: 	momentum: 0.1085628386749145
# wandb: 	rho: 0.9337232133640996
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_011511-6zxxjczl</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/6zxxjczl" target="_blank">playful-sweep-49</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 373)               292805
#
#  dense_1 (Dense)             (None, 230)               86020
#
#  dense_2 (Dense)             (None, 168)               38808
#
#  dense_3 (Dense)             (None, 120)               20280
#
#  dense_4 (Dense)             (None, 10)                1210
#
# =================================================================
# Total params: 439,123
# Trainable params: 439,123
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>val_loss</td><td>█▃▅▄▂▄▁▂▂▂▁▁▁▁▂▁▂▂▃▃▅▅▂▂▂▂▂▃▃▅▄▃▅▄</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▆▅▅▆▅▇▆▇▆▇▇▇▇▇█▇▇▇▇▆▇▇██████▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00044</td></tr><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.33452</td></tr><tr><td>epoch</td><td>33</td></tr><tr><td>loss</td><td>0.11037</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.95823</td></tr><tr><td>val_loss</td><td>0.45669</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.89233</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">playful-sweep-49</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/6zxxjczl" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/6zxxjczl</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_011511-6zxxjczl/logs</code>
# wandb: Agent Starting Run: nyg4r5il with config:
# wandb: 	batch_size: 32
# wandb: 	dense_1: 474
# wandb: 	dense_2: 243
# wandb: 	dense_3: 188
# wandb: 	dense_4: 123
# wandb: 	epochs: 35
# wandb: 	learning_rate: 0.002561022651486402
# wandb: 	momentum: 0.10579060790345927
# wandb: 	rho: 0.9634445046386808
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_011607-nyg4r5il</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/nyg4r5il" target="_blank">different-sweep-50</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/9v74y3nr</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 474)               372090
#
#  dense_1 (Dense)             (None, 243)               115425
#
#  dense_2 (Dense)             (None, 188)               45872
#
#  dense_3 (Dense)             (None, 123)               23247
#
#  dense_4 (Dense)             (None, 10)                1240
#
# =================================================================
# Total params: 557,874
# Trainable params: 557,874
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▂▃▃▃▃</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▇▇▇▇▇▇▇████████████████▇████▇▇▇▇</td></tr><tr><td>val_loss</td><td>▃▂▁▂▂▁▂▂▂▂▂▂▃▃▃▃▃▃▃▅▄▄▄▇▄▄▄▆▅▅▅▅▅█▅</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▁▆▆▇▇█▆▆▆▅█▄▇▆▆▇▆▇▆▅▇█▆▇█▇▆▄▇█▆▅▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00056</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.38425</td></tr><tr><td>epoch</td><td>34</td></tr><tr><td>loss</td><td>0.40281</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.87875</td></tr><tr><td>val_loss</td><td>0.6491</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.8465</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">different-sweep-50</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/nyg4r5il" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/nyg4r5il</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_011607-nyg4r5il/logs</code>

# %% [markdown]
# ## Show best hyperparameters

# %%
api = wandb.Api()
sweep = api.sweep("nsiete23/tf_mlp/sweeps/" + sweep_id)

best_run = sweep.best_run()
print(best_run.id)
pprint(best_run.config)
# Out:
# wandb: Sorting runs by +summary_metrics.val_loss
# yghzx9su
# {'batch_size': 256,
#  'dense_1': 363,
#  'dense_2': 246,
#  'dense_3': 147,
#  'dense_4': 99,
#  'epochs': 15,
#  'learning_rate': 0.001266287404751428,
#  'momentum': 0.27566146279392545,
#  'rho': 0.9841212943927308}

# %% [markdown]
# ## Finish Wandb run

# %%
wandb.finish()
