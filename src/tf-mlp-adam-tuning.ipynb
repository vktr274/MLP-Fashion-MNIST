# %% [markdown]
# # MLP with Adam Using Tensorflow - Tuning

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
import wandb
from pprint import pprint

from tf_utils import create_model, train_model

# %% [markdown]
# ## Login to Wandb

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ## Load Fashion-MNIST

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# ## Define sweep agent function

# %%
def sweep_train():
    default_config = {
        'dense_1': 512,
        'dense_2': 256,
        'dense_3': 256,
        'dense_4': 64,
        'learning_rate': 0.001,
        'beta_1': 0.9,
        'beta_2': 0.999,
        'epochs': 50,
        'batch_size': 128,
    }

    wandb.init(config=default_config)

    config = wandb.config

    mlp = create_model(config)
    mlp.summary()
    mlp.compile(
        optimizer=Adam(learning_rate=config.learning_rate, beta_1=config.beta_1, beta_2=config.beta_2),
        loss=SparseCategoricalCrossentropy(),
        metrics=[SparseCategoricalAccuracy()]
    )
    _ = train_model(mlp, config, x_train, y_train, verbose=0)

# %% [markdown]
# ## Configure Wandb Sweep for hyperparameter tuning

# %%
sweep_config = {
    'name': 'tf-adam-sweep',
    'method': 'bayes',
    'metric': {
        'name': 'val_loss',
        'goal': 'minimize'
    },
    'early_terminate':{
        'type': 'hyperband',
        'min_iter': 2
    },
    'parameters': {
        'batch_size': {
            'values': [16, 32, 64, 128, 256]
        },
        'epochs': {
            'min': 15,
            'max': 50
        },
        'learning_rate': {
            'min': 0.0001,
            'max': 0.1
        },
        'beta_1': {
            'min': 0.9,
            'max': 0.999
        },
        'beta_2': {
            'min': 0.99,
            'max': 0.9999
        },
        'dense_1': {
            'min': 256,
            'max': 512
        },
        'dense_2': {
            'min': 128,
            'max': 256
        },
        'dense_3': {
            'min': 128,
            'max': 256
        },
        'dense_4': {
            'min': 32,
            'max': 128
        }
    }
}

pprint(sweep_config)

sweep_id = wandb.sweep(sweep_config, project='tf_mlp')
# Out:
# {'early_terminate': {'min_iter': 2, 'type': 'hyperband'},
#  'method': 'bayes',
#  'metric': {'goal': 'minimize', 'name': 'val_loss'},
#  'name': 'tf-adam-sweep',
#  'parameters': {'batch_size': {'values': [16, 32, 64, 128, 256]},
#                 'beta_1': {'max': 0.999, 'min': 0.9},
#                 'beta_2': {'max': 0.9999, 'min': 0.99},
#                 'dense_1': {'max': 512, 'min': 256},
#                 'dense_2': {'max': 256, 'min': 128},
#                 'dense_3': {'max': 256, 'min': 128},
#                 'dense_4': {'max': 128, 'min': 32},
#                 'epochs': {'max': 50, 'min': 15},
#                 'learning_rate': {'max': 0.1, 'min': 0.0001}}}
# Create sweep with ID: 12a25071
# Sweep URL: https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071

# %% [markdown]
# ## Run sweep

# %%
wandb.agent(sweep_id, function=sweep_train, count=50)
# Out:
# wandb: Agent Starting Run: qdcc9m2a with config:
# wandb: 	batch_size: 32
# wandb: 	beta_1: 0.9055461392449808
# wandb: 	beta_2: 0.9955683606550336
# wandb: 	dense_1: 502
# wandb: 	dense_2: 150
# wandb: 	dense_3: 227
# wandb: 	dense_4: 123
# wandb: 	epochs: 48
# wandb: 	learning_rate: 0.09416619525165897
# wandb: Currently logged in as: v-modroczky (nsiete23). Use `wandb login --relogin` to force relogin
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_232311-qdcc9m2a</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/qdcc9m2a" target="_blank">golden-sweep-1</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 502)               394070
#
#  dense_1 (Dense)             (None, 150)               75450
#
#  dense_2 (Dense)             (None, 227)               34277
#
#  dense_3 (Dense)             (None, 123)               28044
#
#  dense_4 (Dense)             (None, 10)                1240
#
# =================================================================
# Total params: 533,081
# Trainable params: 533,081
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▄▃▃▂▅▃▅▅▃█▄▃▄▄▂▃▄▅▁▂▂▃▆▁▃▂▇▃▅▇▃▄▄▅▆▅▃▄▃▄</td></tr><tr><td>val_loss</td><td>▂▄█▃▇▆▆▁▂▂▄▃▂▁▄▃▁▄▃▁▃▄▃▃▃▃▂▆▂▂▃▃▃▃▂▂▃▃▅▃</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▅▃▁███▅▃▆█▅▅▅▅▃█▅█▅█▃▃▅▃▃▃▁▅█▃▅█▆▆██▃▅█▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00053</td></tr><tr><td>best_epoch</td><td>35</td></tr><tr><td>best_val_loss</td><td>2.30686</td></tr><tr><td>epoch</td><td>47</td></tr><tr><td>loss</td><td>2.31525</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.10027</td></tr><tr><td>val_loss</td><td>2.31676</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.10033</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">golden-sweep-1</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/qdcc9m2a" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/qdcc9m2a</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_232311-qdcc9m2a/logs</code>
# wandb: Agent Starting Run: nnzsrrxb with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.941964814245118
# wandb: 	beta_2: 0.994023947453032
# wandb: 	dense_1: 305
# wandb: 	dense_2: 183
# wandb: 	dense_3: 206
# wandb: 	dense_4: 58
# wandb: 	epochs: 32
# wandb: 	learning_rate: 0.03703548823282531
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_232703-nnzsrrxb</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/nnzsrrxb" target="_blank">fresh-sweep-2</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 305)               239425
#
#  dense_1 (Dense)             (None, 183)               55998
#
#  dense_2 (Dense)             (None, 206)               37904
#
#  dense_3 (Dense)             (None, 58)                12006
#
#  dense_4 (Dense)             (None, 10)                590
#
# =================================================================
# Total params: 345,923
# Trainable params: 345,923
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▇▇██████████████████▇████████</td></tr><tr><td>val_loss</td><td>█▄▄▂▃▂▁▂▁▁▁▃▁▁▂▂▁▂▂▁▂▂▂▃▃▁▂▁▂▂▂▁</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▅▆▇▇██▇▇██▇█▇███▇███▇█▆▇█▇█▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00035</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.57257</td></tr><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>0.56525</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.80292</td></tr><tr><td>val_loss</td><td>0.59072</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.80033</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fresh-sweep-2</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/nnzsrrxb" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/nnzsrrxb</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_232703-nnzsrrxb/logs</code>
# wandb: Agent Starting Run: 4xtrgop1 with config:
# wandb: 	batch_size: 32
# wandb: 	beta_1: 0.9457768261413304
# wandb: 	beta_2: 0.9929244503361966
# wandb: 	dense_1: 499
# wandb: 	dense_2: 131
# wandb: 	dense_3: 211
# wandb: 	dense_4: 100
# wandb: 	epochs: 24
# wandb: 	learning_rate: 0.010695832123544496
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_232811-4xtrgop1</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/4xtrgop1" target="_blank">earthy-sweep-3</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 499)               391715
#
#  dense_1 (Dense)             (None, 131)               65500
#
#  dense_2 (Dense)             (None, 211)               27852
#
#  dense_3 (Dense)             (None, 100)               21200
#
#  dense_4 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 507,277
# Trainable params: 507,277
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▂▂▂▂▂▁▁▁▁▂▁▃▃▂▂▂▂▃</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▆▆▇▇▇▇▇▇▇▇████▇█▇▇███▇▇</td></tr><tr><td>val_loss</td><td>▂▂▂▂▃▂▂▅▂▆▂▃▁▂▃▃▃▄█▃▅█▅█</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▂▃▃▅▄▂▂▅▆▃▇▇█▆▅▄▃▄▄█▇▁▂▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00051</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.47334</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.49793</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.84217</td></tr><tr><td>val_loss</td><td>0.77344</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.83075</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">earthy-sweep-3</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/4xtrgop1" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/4xtrgop1</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_232811-4xtrgop1/logs</code>
# wandb: Agent Starting Run: 20q1fnt0 with config:
# wandb: 	batch_size: 64
# wandb: 	beta_1: 0.9247684002500548
# wandb: 	beta_2: 0.999823216633493
# wandb: 	dense_1: 443
# wandb: 	dense_2: 165
# wandb: 	dense_3: 191
# wandb: 	dense_4: 70
# wandb: 	epochs: 38
# wandb: 	learning_rate: 0.09926648137767496
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233010-20q1fnt0</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/20q1fnt0" target="_blank">noble-sweep-4</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 443)               347755
#
#  dense_1 (Dense)             (None, 165)               73260
#
#  dense_2 (Dense)             (None, 191)               31706
#
#  dense_3 (Dense)             (None, 70)                13440
#
#  dense_4 (Dense)             (None, 10)                710
#
# =================================================================
# Total params: 466,871
# Trainable params: 466,871
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▇▂▄▅▃▇▆▅▄▆▄▁▅▇█▃▁▅▆▄</td></tr><tr><td>val_loss</td><td>▁▂▃▅▃▅▃▂▅▆▂▆▄▃▃█▁▃▃▅</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>█▅▃▆█▆█▆▅▅▅▅▃▃▅▁█▆█▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00047</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>2.30361</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>2.31157</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.09898</td></tr><tr><td>val_loss</td><td>2.31793</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.09833</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">noble-sweep-4</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/20q1fnt0" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/20q1fnt0</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233010-20q1fnt0/logs</code>
# wandb: Agent Starting Run: hpcrs0ab with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.9591544234365096
# wandb: 	beta_2: 0.9903891493448778
# wandb: 	dense_1: 324
# wandb: 	dense_2: 164
# wandb: 	dense_3: 198
# wandb: 	dense_4: 72
# wandb: 	epochs: 29
# wandb: 	learning_rate: 0.01008544856907484
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233150-hpcrs0ab</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/hpcrs0ab" target="_blank">efficient-sweep-5</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 324)               254340
#
#  dense_1 (Dense)             (None, 164)               53300
#
#  dense_2 (Dense)             (None, 198)               32670
#
#  dense_3 (Dense)             (None, 72)                14328
#
#  dense_4 (Dense)             (None, 10)                730
#
# =================================================================
# Total params: 355,368
# Trainable params: 355,368
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▆▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▃▂▃▃▂▂▁▁▂▂▃▂▃▄▂▂▃▃▃▄▃▅▄</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▆▇█▇▇▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00036</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.35522</td></tr><tr><td>epoch</td><td>28</td></tr><tr><td>loss</td><td>0.25196</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.90894</td></tr><tr><td>val_loss</td><td>0.39617</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.88542</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">efficient-sweep-5</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/hpcrs0ab" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/hpcrs0ab</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233150-hpcrs0ab/logs</code>
# wandb: Agent Starting Run: qqb5dtku with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.9250510279922884
# wandb: 	beta_2: 0.9905052005915664
# wandb: 	dense_1: 288
# wandb: 	dense_2: 242
# wandb: 	dense_3: 232
# wandb: 	dense_4: 80
# wandb: 	epochs: 17
# wandb: 	learning_rate: 0.0011498246866222658
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233257-qqb5dtku</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/qqb5dtku" target="_blank">rich-sweep-6</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 288)               226080
#
#  dense_1 (Dense)             (None, 242)               69938
#
#  dense_2 (Dense)             (None, 232)               56376
#
#  dense_3 (Dense)             (None, 80)                18640
#
#  dense_4 (Dense)             (None, 10)                810
#
# =================================================================
# Total params: 371,844
# Trainable params: 371,844
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▄▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>val_loss</td><td>█▅▃▄▂▃▂▁▁▂▁▂▁▁▁▂▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▃▅▄▅▆▆▇▇▆█▇███▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00037</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.31143</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.17596</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.93246</td></tr><tr><td>val_loss</td><td>0.32723</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.8905</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rich-sweep-6</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/qqb5dtku" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/qqb5dtku</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233257-qqb5dtku/logs</code>
# wandb: Agent Starting Run: fml5k21d with config:
# wandb: 	batch_size: 32
# wandb: 	beta_1: 0.9780679993488128
# wandb: 	beta_2: 0.9912594361660652
# wandb: 	dense_1: 329
# wandb: 	dense_2: 217
# wandb: 	dense_3: 252
# wandb: 	dense_4: 54
# wandb: 	epochs: 20
# wandb: 	learning_rate: 0.0037183337326787617
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233349-fml5k21d</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/fml5k21d" target="_blank">absurd-sweep-7</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 329)               258265
#
#  dense_1 (Dense)             (None, 217)               71610
#
#  dense_2 (Dense)             (None, 252)               54936
#
#  dense_3 (Dense)             (None, 54)                13662
#
#  dense_4 (Dense)             (None, 10)                550
#
# =================================================================
# Total params: 399,023
# Trainable params: 399,023
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▅▆▆▇▇▇▇▇▇▇████████</td></tr><tr><td>val_loss</td><td>▆▃▃▁▄▅▄▁▂▃▄▁▂▃▃▁█▇█▇</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▄▃▆▅▄▆▇▅▆▄▇█▆▆█▇█▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.0004</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.38234</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.3023</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.89358</td></tr><tr><td>val_loss</td><td>0.46091</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.86467</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">absurd-sweep-7</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/fml5k21d" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/fml5k21d</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233349-fml5k21d/logs</code>
# wandb: Agent Starting Run: vw7ynyxf with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.974542160927393
# wandb: 	beta_2: 0.9901804451496397
# wandb: 	dense_1: 380
# wandb: 	dense_2: 204
# wandb: 	dense_3: 249
# wandb: 	dense_4: 32
# wandb: 	epochs: 22
# wandb: 	learning_rate: 0.02627930081124824
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233532-vw7ynyxf</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/vw7ynyxf" target="_blank">icy-sweep-8</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 380)               298300
#
#  dense_1 (Dense)             (None, 204)               77724
#
#  dense_2 (Dense)             (None, 249)               51045
#
#  dense_3 (Dense)             (None, 32)                8000
#
#  dense_4 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 435,399
# Trainable params: 435,399
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▄▇███████████████████</td></tr><tr><td>val_loss</td><td>█▇▂▂▂▂▂▁▁▁▁▁▁▁▁▃▁▁▁▁▁▁</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▂▇▇█▇▇███████████▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00044</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>1.20058</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>1.17828</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.478</td></tr><tr><td>val_loss</td><td>1.21167</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.47217</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">icy-sweep-8</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/vw7ynyxf" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/vw7ynyxf</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233532-vw7ynyxf/logs</code>
# wandb: Agent Starting Run: fgnkpjr1 with config:
# wandb: 	batch_size: 64
# wandb: 	beta_1: 0.9429665148103002
# wandb: 	beta_2: 0.9925600684575656
# wandb: 	dense_1: 307
# wandb: 	dense_2: 194
# wandb: 	dense_3: 198
# wandb: 	dense_4: 102
# wandb: 	epochs: 23
# wandb: 	learning_rate: 0.0030259295998909543
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233624-fgnkpjr1</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/fgnkpjr1" target="_blank">earthy-sweep-9</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 307)               240995
#
#  dense_1 (Dense)             (None, 194)               59752
#
#  dense_2 (Dense)             (None, 198)               38610
#
#  dense_3 (Dense)             (None, 102)               20298
#
#  dense_4 (Dense)             (None, 10)                1030
#
# =================================================================
# Total params: 360,685
# Trainable params: 360,685
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇███████</td></tr><tr><td>val_loss</td><td>▇▆▅▃▅▃▂▃▂▁▃▁▃█▄▃▄▄▆▅██▇</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▃▄▆▆▆▇▆▇▇▇█▇▆█▇█▇▇▇▇█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00036</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>0.34002</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.23002</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.91621</td></tr><tr><td>val_loss</td><td>0.43507</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.88258</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">earthy-sweep-9</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/fgnkpjr1" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/fgnkpjr1</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233624-fgnkpjr1/logs</code>
# wandb: Agent Starting Run: nlmeu15j with config:
# wandb: 	batch_size: 128
# wandb: 	beta_1: 0.9950173271388416
# wandb: 	beta_2: 0.9913666077907416
# wandb: 	dense_1: 261
# wandb: 	dense_2: 141
# wandb: 	dense_3: 194
# wandb: 	dense_4: 107
# wandb: 	epochs: 18
# wandb: 	learning_rate: 0.000791861964955855
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233742-nlmeu15j</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/nlmeu15j" target="_blank">scarlet-sweep-10</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 261)               204885
#
#  dense_1 (Dense)             (None, 141)               36942
#
#  dense_2 (Dense)             (None, 194)               27548
#
#  dense_3 (Dense)             (None, 107)               20865
#
#  dense_4 (Dense)             (None, 10)                1080
#
# =================================================================
# Total params: 291,320
# Trainable params: 291,320
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▂▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▄▅▅▆▆▇▇▇▇▇▇▇▇████</td></tr><tr><td>val_loss</td><td>█▆▅▃▂▂▂▁▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▃▄▆▆▇▇▇▇▇▇█▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00029</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.30599</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.18411</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.92935</td></tr><tr><td>val_loss</td><td>0.32697</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.895</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">scarlet-sweep-10</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/nlmeu15j" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/nlmeu15j</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233742-nlmeu15j/logs</code>
# wandb: Agent Starting Run: s8n23te1 with config:
# wandb: 	batch_size: 128
# wandb: 	beta_1: 0.9484545584631338
# wandb: 	beta_2: 0.992782895927994
# wandb: 	dense_1: 272
# wandb: 	dense_2: 134
# wandb: 	dense_3: 232
# wandb: 	dense_4: 74
# wandb: 	epochs: 23
# wandb: 	learning_rate: 0.004176293709502716
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233839-s8n23te1</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/s8n23te1" target="_blank">distinctive-sweep-11</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 272)               213520
#
#  dense_1 (Dense)             (None, 134)               36582
#
#  dense_2 (Dense)             (None, 232)               31320
#
#  dense_3 (Dense)             (None, 74)                17242
#
#  dense_4 (Dense)             (None, 10)                750
#
# =================================================================
# Total params: 299,414
# Trainable params: 299,414
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▄▅▆▆▆▆▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>val_loss</td><td>█▆▃▄▃▃▁▄▂▂▄▂▄▂▃▄▄▅█▅▅▅▇</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▂▅▅▅▆▇▃▇█▆█▇██▆█▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.0003</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.32572</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.22812</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.91881</td></tr><tr><td>val_loss</td><td>0.41833</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.88383</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">distinctive-sweep-11</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/s8n23te1" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/s8n23te1</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230310_233839-s8n23te1/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: lgocg9xl with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.9536129572235824
# wandb: 	beta_2: 0.9924920860176142
# wandb: 	dense_1: 258
# wandb: 	dense_2: 164
# wandb: 	dense_3: 155
# wandb: 	dense_4: 66
# wandb: 	epochs: 22
# wandb: 	learning_rate: 0.005573776299458383
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230310_233946-lgocg9xl</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/lgocg9xl" target="_blank">fiery-sweep-12</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 258)               202530
#
#  dense_1 (Dense)             (None, 164)               42476
#
#  dense_2 (Dense)             (None, 155)               25575
#
#  dense_3 (Dense)             (None, 66)                10296
#
#  dense_4 (Dense)             (None, 10)                670
#
# =================================================================
# Total params: 281,547
# Trainable params: 281,547
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
# wandb: 	learning_rate: 0.008898951745587667
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_001657-hx0jis8n</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/hx0jis8n" target="_blank">eager-sweep-47</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 257)               201745
#
#  dense_1 (Dense)             (None, 136)               35088
#
#  dense_2 (Dense)             (None, 159)               21783
#
#  dense_3 (Dense)             (None, 100)               16000
#
#  dense_4 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 275,626
# Trainable params: 275,626
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▆▇▇▇▇▇█████████</td></tr><tr><td>val_loss</td><td>█▅▄▂▂▂▃▁▂▁▄▁▃▂▄▂▁▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▄▄▅▅▆▆▇▆▆▆▇▇▇▆▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00028</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.34985</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.25904</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.90442</td></tr><tr><td>val_loss</td><td>0.35831</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.88267</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">eager-sweep-47</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/hx0jis8n" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/hx0jis8n</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_001657-hx0jis8n/logs</code>
# wandb: Agent Starting Run: iklvrsq8 with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.9867983216864308
# wandb: 	beta_2: 0.9939076262444322
# wandb: 	dense_1: 310
# wandb: 	dense_2: 182
# wandb: 	dense_3: 224
# wandb: 	dense_4: 41
# wandb: 	epochs: 15
# wandb: 	learning_rate: 0.007630100864385024
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_001749-iklvrsq8</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/iklvrsq8" target="_blank">neat-sweep-48</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 310)               243350
#
#  dense_1 (Dense)             (None, 182)               56602
#
#  dense_2 (Dense)             (None, 224)               40992
#
#  dense_3 (Dense)             (None, 41)                9225
#
#  dense_4 (Dense)             (None, 10)                420
#
# =================================================================
# Total params: 350,589
# Trainable params: 350,589
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>█▃▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▆▆▇▇▇▇████████</td></tr><tr><td>val_loss</td><td>█▅▃▃▂▂▂▂▂▁▁▁▁▂▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▄▆▆▇▇▇▇▇█▇█▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00035</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.3529</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.25956</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.90485</td></tr><tr><td>val_loss</td><td>0.37363</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.87892</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">neat-sweep-48</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/iklvrsq8" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/iklvrsq8</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_001749-iklvrsq8/logs</code>
# wandb: Agent Starting Run: bznqqjeq with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.9355128911534324
# wandb: 	beta_2: 0.9910382609109922
# wandb: 	dense_1: 273
# wandb: 	dense_2: 151
# wandb: 	dense_3: 200
# wandb: 	dense_4: 87
# wandb: 	epochs: 25
# wandb: 	learning_rate: 0.008662586331871275
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_001841-bznqqjeq</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/bznqqjeq" target="_blank">rural-sweep-49</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 273)               214305
#
#  dense_1 (Dense)             (None, 151)               41374
#
#  dense_2 (Dense)             (None, 200)               30400
#
#  dense_3 (Dense)             (None, 87)                17487
#
#  dense_4 (Dense)             (None, 10)                880
#
# =================================================================
# Total params: 304,446
# Trainable params: 304,446
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▆▆▆▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>val_loss</td><td>█▃▂▂▄▄▂▂▁▂▁▁▂▁▂▃▂▁▃▁▃▃▂▆▄</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▅▅▆▅▅▆▆▆▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.0003</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.35723</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.25335</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.90977</td></tr><tr><td>val_loss</td><td>0.41014</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.87892</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rural-sweep-49</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/bznqqjeq" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/bznqqjeq</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_001841-bznqqjeq/logs</code>
# wandb: Agent Starting Run: vo7fu6ix with config:
# wandb: 	batch_size: 256
# wandb: 	beta_1: 0.9888964593164976
# wandb: 	beta_2: 0.992148909221722
# wandb: 	dense_1: 272
# wandb: 	dense_2: 248
# wandb: 	dense_3: 234
# wandb: 	dense_4: 125
# wandb: 	epochs: 29
# wandb: 	learning_rate: 0.022947780943994897
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230311_001939-vo7fu6ix</code>
# Syncing run <strong><a href="https://wandb.ai/nsiete23/tf_mlp/runs/vo7fu6ix" target="_blank">dashing-sweep-50</a></strong> to <a href="https://wandb.ai/nsiete23/tf_mlp" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071" target="_blank">https://wandb.ai/nsiete23/tf_mlp/sweeps/12a25071</a>
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 28, 28)            0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 272)               213520
#
#  dense_1 (Dense)             (None, 248)               67704
#
#  dense_2 (Dense)             (None, 234)               58266
#
#  dense_3 (Dense)             (None, 125)               29375
#
#  dense_4 (Dense)             (None, 10)                1260
#
# =================================================================
# Total params: 370,125
# Trainable params: 370,125
# Non-trainable params: 0
# _________________________________________________________________
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▃▂▂▂▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅▆▇▇▇▇▇▇▇█████▇███▇▇▇███████</td></tr><tr><td>val_loss</td><td>█▇▃▃▁▂▂▂▁▂▃▁▃▁▂▂▃▃▃▃▆▃▂▅▂▂▂▃▂</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▃▅▅▇▇██▇▇▅▇▆█▇▇▇▇▇▆▆▆█▇██▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>GFLOPS</td><td>0.00037</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.44566</td></tr><tr><td>epoch</td><td>28</td></tr><tr><td>loss</td><td>0.39973</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.8644</td></tr><tr><td>val_loss</td><td>0.47245</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.84725</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dashing-sweep-50</strong>: <a href="https://wandb.ai/nsiete23/tf_mlp/runs/vo7fu6ix" target="_blank">https://wandb.ai/nsiete23/tf_mlp/runs/vo7fu6ix</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230311_001939-vo7fu6ix/logs</code>

# %% [markdown]
# ## Show best hyperparameters

# %%
api = wandb.Api()
sweep = api.sweep("nsiete23/tf_mlp/sweeps/" + sweep_id)

best_run = sweep.best_run()
print(best_run.id)
pprint(best_run.config)
# Out:
# wandb: Sorting runs by +summary_metrics.val_loss
# 40dunp3m
# {'batch_size': 128,
#  'beta_1': 0.986435025614692,
#  'beta_2': 0.9904482393527106,
#  'dense_1': 485,
#  'dense_2': 176,
#  'dense_3': 131,
#  'dense_4': 122,
#  'epochs': 19,
#  'learning_rate': 0.00012885226472854095}

# %% [markdown]
# ## Finish Wandb run

# %%
wandb.finish()
